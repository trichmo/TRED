# %%
import matplotlib
from TopologyFunctionality.Octree import Octree

Octree(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-fd5587b88cc9> in <module>()
#       1 import matplotlib
# ----> 2 from TopologyFunctionality.Octree import Octree
#       3
#       4 Octree(2)
#
# C:\Users\turne\Masters\Wearable\Python_Topology\TopologyFunctionality\Octree\Octree.py in <module>()
# ----> 1 class Octree(object):
#       2
#       3         firstLevel = property(getFirstLevel, setFirstLevel)
#       4         bounds = property(getBounds,setBound)
#       5         points = property(getPoints,setPoints)
#
# C:\Users\turne\Masters\Wearable\Python_Topology\TopologyFunctionality\Octree\Octree.py in Octree()
#       1 class Octree(object):
#       2
# ----> 3         firstLevel = property(getFirstLevel, setFirstLevel)
#       4         bounds = property(getBounds,setBound)
#       5         points = property(getPoints,setPoints)
#
# NameError: name 'getFirstLevel' is not defined

# %%
# %matplotlib notebook 

from __future__ import print_function
import sys
import numpy as np
import matplotlib.pyplot as plt


def press(event):
    print('press', event.key)
    sys.stdout.flush()
    if event.key == 'x':
        visible = xl.get_visible()
        xl.set_visible(not visible)
        fig.canvas.draw()

fig, ax = plt.subplots()

fig.canvas.mpl_connect('key_press_event', press)

ax.plot(np.random.rand(12), np.random.rand(12), 'go')
xl = ax.set_xlabel('easy come, easy go')

plt.show()
# Out:
# <img src="data:image/png;base64,...">
